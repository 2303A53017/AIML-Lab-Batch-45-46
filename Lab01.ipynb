# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A53017/AIML-Lab-Batch-45-46/blob/main/Lab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = pd.read_table("/content/drive/MyDrive/pp.txt")

# %%
df1
# Out:
#   First line: This is a test file
# 0             This is second line
# 1                      third line
# 2          and subsiquent lines..
# 3                      and more..

# %%
  data2 = pd.read_csv("/content/drive/MyDrive/Spd.csv")

# %%
data2
# Out:
#   First line: This is a test file
# 0             This is second line
# 1                      third line
# 2          and subsiquent lines..
# 3                      and more..

# %%
data3 = pd.read_excel("/content/drive/MyDrive/Historicalinvesttemp.xlsx")

# %%
data3
# Out:
#    Unnamed: 0                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0         NaN                               NaN        NaN        NaN
# 1         NaN                               NaN        NaN        NaN
# 2         NaN                               NaN        NaN        NaN
# 3         NaN                               NaN        NaN        NaN
# 4         NaN  Annual Returns on Investments in        NaN        NaN
# ..        ...                               ...        ...        ...
# 85       2007                            0.0549     0.0988     0.0466
# 86       2008                             -0.37     0.2587      0.016
# 87       2009                            0.2646     -0.149      0.001
# 88        NaN                            stocks     tbills      bonds
# 89   averages                               NaN        NaN        NaN
#
# [90 rows x 4 columns]

# %%
import numpy as np
from queue import Queue

# %%
graph = {
    0: [1,2,3],
    1: [0,2],
    2: [0,1,3,5],
    3: [0,2,4],
    4: [3,5,7],
    5: [4,6,7],
    6: [5,7],
    7: [4,5,6],
    8: []
}
print("The adjacency List representating the graphics : ")
print(graph)
# Out:
# The adjacency List representating the graphics :
# {0: [1, 2, 3], 1: [0, 2], 2: [0, 1, 3, 5], 3: [0, 2, 4], 4: [3, 5, 7], 5: [4, 6, 7], 6: [5, 7], 7: [4, 5, 6], 8: []}

# %%
def bfs(graph,source):
  Q = Queue()
  visited_vertices = set()
  Q.put(source)
  visited_vertices.update({source})

  while not Q.empty():
    vertex = Q.get()
    print(vertex, end="-->")
    for u in graph[vertex]:
      if u not in visited_vertices:
        Q.put(u)
        visited_vertices.update({u})


print("BFS traversal of graph with source 0 is :")
bfs(graph, 0)
# Out:
# BFS traversal of graph with source 0 is :
# 0-->1-->2-->3-->5-->4-->6-->7-->
